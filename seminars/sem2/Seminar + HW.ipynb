# %% [markdown]
# Задание 1.
# 1. Скачать данные по ссылке
# https://www.kaggle.com/datasets/ionaskel/laptop-prices
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк
# 4. Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
# Out:
# C:\Users\mirsoat\AppData\Local\Temp\ipykernel_9368\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', encoding='latin1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %% [markdown]
# Задание 2.
# Проведите первичный анализ данных
# 1. Изучите типы данных
# 2. Найдите количество пропущенных ячеек в данных
# 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
Задание 3.
Ответьте на несколько вопросов
3.1 Ноутбуков от какой компании больше всего в наборе
данных?
3.2 Какая минимальная и максимальная стоимость у
ноутбуков в данных?
3.3 Какой самый дорогой ноутбук в данных?
Выведите все характеристики только по этому ноутбуку
Если таких ноутбуков несколько, то выводите их всех

# %%
df.describe(include=['object', 'float'])
# Out:
#        Company Product  TypeName       Inches   ScreenResolution  \
# count     1303    1303      1303  1303.000000               1303
# unique      19     618         6          NaN                 40
# top       Dell  XPS 13  Notebook          NaN  Full HD 1920x1080
# freq       297      30       727          NaN                507
# mean       NaN     NaN       NaN    15.017191                NaN
# std        NaN     NaN       NaN     1.426304                NaN
# min        NaN     NaN       NaN    10.100000                NaN
# 25%        NaN     NaN       NaN    14.000000                NaN
# 50%        NaN     NaN       NaN    15.600000                NaN
# 75%        NaN     NaN       NaN    15.600000                NaN
# max        NaN     NaN       NaN    18.400000                NaN
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# ...

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Price_euros'].min()
# Out:
# 174.0

# %%
df['Price_euros'].max()
# Out:
# 6099.0

# %%
df['Price_euros'].max(), df['Price_euros'].min()
# Out:
# (6099.0, 174.0)

# %%
df.sort_values('Price_euros', ascending=False).head(3)
# Out:
#      laptop_ID Company       Product  TypeName  Inches  \
# 196        200   Razer     Blade Pro    Gaming    17.3
# 830        839   Razer     Blade Pro    Gaming    17.3
# 610        617  Lenovo  Thinkpad P51  Notebook    15.6
#
#                         ScreenResolution                            Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz  32GB
# 830  4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz  32GB
# 610      IPS Panel 4K Ultra HD 3840x2160  Intel Xeon E3-1535M v6 3.1GHz  32GB
#
#         Memory                      Gpu       OpSys  Weight  Price_euros
# 196    1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0
# 830  512GB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       5499.0
# 610    1TB SSD     Nvidia Quadro M2200M  Windows 10   2.5kg       4899.0

# %%
df.sort_values('Price_euros', ascending=False).iloc[0]
# Out:
# laptop_ID                                           200
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                32GB
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                           3.49kg
# Price_euros                                      6099.0
# Name: 196, dtype: object

# %% [markdown]
# Задание 4.
# Ответьте на несколько вопросов
# 4.1 Найдите ноутбуки с самой маленькой диагональю в
# данных?
# Выведите только следующие характеристики:
# 1. Компания
# 2. Типа ноутбука
# 3. Диагональ
# 4. Стоимость
# Если таких ноутбуков несколько, то выводите их всех
# 4.2 Сколько стоит самый дорогой ноутбук у компании HP?
# 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении
# относительно всех ультрабуков

# %%
df[df['Inches'] == df['Inches'].min()][['Company', 'TypeName', 'Inches', 'Price_euros']]
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %%
df[df['Company'] == 'HP'].sort_values('Price_euros', ascending=False).iloc[0]
# Out:
# laptop_ID                                     758
# Company                                        HP
# Product                                  Zbook 17
# TypeName                              Workstation
# Inches                                       17.3
# ScreenResolution      IPS Panel Full HD 1920x1080
# Cpu                 Intel Xeon E3-1535M v5 2.9GHz
# Ram                                          16GB
# Memory                                  256GB SSD
# Gpu                          Nvidia Quadro M2000M
# OpSys                                   Windows 7
# Weight                                        3kg
# Price_euros                                4389.0
# Name: 749, dtype: object

# %%
df[(df['TypeName'] == 'Ultrabook') & (df['Ram'] == '8GB')].count()
# Out:
# laptop_ID           140
# Company             140
# Product             140
# TypeName            140
# Inches              140
# ScreenResolution    140
# Cpu                 140
# Ram                 140
# Memory              140
# Gpu                 140
# OpSys               140
# Weight              140
# Price_euros         140
# dtype: int64

# %%
ultra = df[df['TypeName'] == 'Ultrabook'].shape[0]
ultra_8gb = df[(df['TypeName'] == 'Ultrabook') & (df['Ram'] == '8GB')].shape[0]
print(f'{ultra_8gb / ultra * 100:0.3f}')
# Out:
# 71.429

# %%
Задание 5.
5.1 Выберите ноутбук клиенту
Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в
стоимости до 500 евро, сколько у него вариантов?
5.2 Выберите ноутбук клиенту
Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX
1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли
подобные ноутбуки?
5.3 Что дешевле?
В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel
Core i7 7600U 2.8GHz?

# %%
proc1 = df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean()
proc2 = df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()

proc1, proc2
# Out:
# (1760.4084246575342, 1915.710769230769)

# %%
df[
    (df['OpSys'] == 'Windows 10') &
    (df['Ram'].isin(['8GB', '16GB'])) &
    (df['Price_euros'] <= 500)
].shape[0]
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 74           76    Acer                             Aspire E5-475  Notebook
# 175         179    Dell                             Inspiron 3567  Notebook
# 256         261      HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook
# 292         297      HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook
# 313         318    Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook
# 365         371      HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook
# 571         578      HP            14-am079na (N3710/8GB/2TB/W10)  Notebook
# 595         602  Lenovo                         IdeaPad 110-15ISK  Notebook
# 634         642    Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook
# 702         710  Lenovo                         IdeaPad 320-15ABR  Notebook
# 1057       1071    Acer                            Aspire ES1-523  Notebook
# ...

# %%
# laptop_choice = df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & ~(df['Inches'] == '15.6')]
# laptop_choice

df[
    (df['Company'] == 'MSI') &
    ~(df['Inches'] == 15.6) &
    (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti')
].head()
# Out:
#       laptop_ID Company        Product TypeName  Inches   ScreenResolution  \
# 330         336     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393         400     MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 724         732     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917         931     MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1156       1174     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# ...

# %% [markdown]
# # HOMEWOKR

# %% [raw]
# Домашнее задание 1
# Анализ датасета с помощью Pandas
# 🌟 Скачать данные по ссылке
# https://www.kaggle.com/datasets/ionaskel/laptop-prices
# 🌟 Считать данные с помощью pandas
# 🌟 Вывести на экран первые 5 строк
# 🌟 Посмотреть на описание признаков и на их содержание

# %%
# import requests as req

# with open('laptop_prices.csv', '+w') as file:
#     file = req.get('https://www.kaggle.com/datasets/ionaskel/laptop-prices')

df2 = pd.read_csv('kc_house_data.csv')

# %%
df2.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Домашнее задание 2
# Анализ датасета с помощью Pandas
# Проведите первичный анализ данных
# 1. Изучите типы данных
# 2. Найдите количество пропущенных ячеек в данных
# 3. Посчитайте основные статистики по всем признакам и
# поизучайте их
# 4. Пишите выводы

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df2.describe(include=['int64', 'float'])
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# Домашнее задание 3
# Анализ датасета с помощью Pandas
# Ответьте на несколько вопросов
# 3.1 В каком диапазоне изменяются стоимости недвижимости?
# 3.2 Какую долю в среднем занимают жилая площадь от всей
# площади по всем домам?
# 3.3 Как много домов с разными этажами в данных?
# 3.4 Насколько хорошие состояния у домов в данных?
# 3.5 Найдите года, когда построили первый дом, когда
# построили последний дом в данных?

# %%
df2['price'].describe(include=['int64', 'float'])
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
living = df2['sqft_living']
lot = df2['sqft_lot']
percentage = living / lot * 100

pd.Series([living, lot, percentage])
# Out:
# 0    0        1180
# 1        2570
# 2         770
# 3   ...
# 1    0         5650
# 1         7242
# 2        10000
# 3...
# 2    0         20.884956
# 1         35.487434
# 2     ...
# dtype: object

# %%
df2['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
df2['floors'].nunique()
# Out:
# 6

# %%
df2['floors'].value_counts()
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
df2[['condition', 'yr_built']].max(), df2[['condition', 'yr_built']].min()
# Out:
# (condition       5
#  yr_built     2015
#  dtype: int64,
#  condition       1
#  yr_built     1900
#  dtype: int64)

# %% [markdown]
# Домашнее задание 4
# Анализ датасета с помощью Pandas
# Ответьте на несколько вопросов
# 4.1 Сколько в сред/самый дорогойнем стоят дома, у которых 2 спальни?
# 4.2 Какая в среднем общая площадь домов, у которых
# стоимость больше 600 000?
# 4.3 Как много домов коснулся ремонт?
# 4.4 Насколько в среднем стоимость домов с оценкой grade
# домов выше 10 отличается от стоимости домов с оценкой grade
# меньше 4?

# %%
df2[df2['bedrooms'] == 2]['price'].mean(), df2[df2['bedrooms'] == 2]['price'].max()
# Out:
# (401372.681884058, 3278000.0)

# %%
df2[df2['price'] >= 600000]['sqft_lot'].mean()
# Out:
# 20454.783537543197

# %%
df2[~(df2['yr_renovated'] == 0)].shape[0]
# Out:
# 914

# %%
h_grade = df2[df2['grade'] >= 10]['price'].mean()
l_grade = df2[df2['grade'] <= 4]['price'].mean()

p = l_grade / h_grade * 100
p
# Out:
# 16.804292458035533

# %%
Домашнее задание 5
Анализ датасета с помощью Pandas
5.1 Выберите дом клиенту
Клиент хочет дом с видом на набережную, как минимум с тремя
ванными и с подвалом. Сколько вариантов есть у клиента?
5.2 Выберите дом клиенту
Клиент хочет дом либо с очень красивым видом из окна, либо с
видом на набережную, в очень хорошем состоянии и год
постройки не меньше 1980 года. В какой ценовом диапазоне
будут дома?
5.3 Выберите дом клиенту
Клиент хочет дом без подвала, с двумя этажами, стоимостью
до 150000. Какая оценка по состоянию у таких домов в
среднем?

# %%
df2[(df2['bathrooms'] >= 3) & (df2['sqft_basement'] > 0) & (df2['waterfront']) > 0].shape[0]
# Out:
# 41

# %%
choice = df2[((df2['waterfront'] == 1) | (df2['view'] == 4)) & (df2['condition'] == 5) & (df2['yr_built'] >= 1980)]['price']

choice.max(), choice.min()
# Out:
# (3000000.0, 1295000.0)

# %%
choice = df2[(df2['sqft_basement'] == 0) & (df2['floors'] == 2) & (df2['price'] <= 150000)]

choice['grade'].mean()
# Out:
# 7.0

# %%
df2.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object
